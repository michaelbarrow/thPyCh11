# %% [markdown]
# ## Chapter 11 - Dictionaries

# %% [markdown]
# Dictionaries are a built-in type in Python.  They are one approach to many very efficient processes.
#
# -- Dictionaries are mappings.
# A dictionary is a like a list, but contains more flexibility.  Instead of associating one element with each non-negative integer index, it can associates each element with a general "key."
#
# These associations can be considered as key-value pairs, much like a word-definition pair (aka an item) in a language dictionary.
#
# This association in math is called a mapping; a dictionary maps a key to a value.  A key should map to one and only one value.  A value could be mapped to by more than one key.

# %%
#Creating a dictionary
#one way to create a dictionary is using the 
#dict() constructor. Our example will be 
#Spanish to English colors
sp2eng = dict() #this creates an empty dictionary
sp2eng
#output is an empty set of {}'s, which denotes
#a dictionary.
# Out:
# {}

# %%
#We can add a key value pair like so:
sp2eng['rojo'] = 'red'
sp2eng
# Out:
# {'rojo': 'red'}

# %%
#another way to create a dictionary is 
#directly using the squiggly brackets.
sp2eng = {'rojo': 'red', 'azul': 'blue'}
sp2eng
# Out:
# {'rojo': 'red', 'azul': 'blue'}

# %%
#Dictionaries are not ordered!
sp2eng['amarillo'] = 'orange??'
sp2eng['verde'] = 'green'
sp2eng['amarillo'] = 'yellow'
display(sp2eng)
#The order may be not the same as how
#you entered them.  
#Dictionaries don't have a first, second, third
#element, they just have items that are matched
#keys to values.
# Out:
# {'rojo': 'red', 'azul': 'blue', 'amarillo': 'yellow', 'verde': 'green'}

# %%
#You can look up/retrieve values
#from their keys
sp2eng['rojo']
# Out:
# 'red'

# %%
#But if you look for a key that's not in the 
#dictionary, you get an error
sp2eng['Rojooooooo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-8fd6fe5ea024> in <module>
#       1 #But if you look for a key that's not in the
#       2 #dictionary, you get an error
# ----> 3 sp2eng['Rojooooooo']
#
# KeyError: 'Rojooooooo'

# %%
#Dictionaries can be converted to list-like
#types, to use list functionality 
#you can retrieve the keys, the values,
#and the items (pairs)
display(sp2eng.keys())
display(sp2eng.values())
display(sp2eng.items())
display('rojo' in sp2eng.keys())
display('rojoooo' in sp2eng.keys())
# Out:
# dict_keys(['rojo', 'azul', 'amarillo', 'verde'])
# dict_values(['red', 'blue', 'yellow', 'green'])
# dict_items([('rojo', 'red'), ('azul', 'blue'), ('amarillo', 'yellow'), ('verde', 'green')])
# True
# False

# %%
#If there is no sorting, how does Python look
#up entries to see if they're there or not?

#Answer: the HASHTABLE / Hash function
#Remarkable part: lookups on a Hash
#take the same amount of time no matter
#how many entries are in the data set.
#This is different than a list, where 
#time increases with size of list.
from time import perf_counter as time
s = []
d = {}
ceiling = 10**7
start=time()
for i in range(ceiling):
    s.append(i)
    d[i] = i
end = time()
loop_time = end-start

start = time()
ceiling-1 in s
end = time()
list_time = end-start

start = time()
ceiling-1 in d.keys()
end = time()
dictionary_time = end-start

print('loop time:', loop_time)
print('list time:',list_time)
print('dictionary time:',dictionary_time)
# Out:
# loop time: 2.1616728489999844
# list time: 0.164864184999999
# dictionary time: 4.164800000694413e-05

# %% [markdown]
# # Applications of a Dictionary

# %% [markdown]
# Suppose you're given a long string, and you want to compute the frequency of each letter in the string. There are a few approaches:
# 1) create 26 variables to store the counts of each letter, loop through the string and update each variable accordingly.
# 2) Create a list with 26 elements.  You could convert each number into an index, then increment the corresponding element on the list each time you see that letter in the string.
# 3) make a dictionary with keys as letters and counters as values.  Dictionaries are set up to do this very efficiently and easily.

# %%
#a histogram is a graphical/numerical collection of 
#counters/frequencies of events.
def histogram(s):
    d = dict()
    for c in s:
        if c not in d:
            d[c] = 1
        else:
            d[c] += 1
    return d

x = histogram('the quick brown fox jumps over the lazy dog')
display(len(x))
x
# Out:
# 27
# {'t': 2,
#  'h': 2,
#  'e': 3,
#  ' ': 8,
#  'q': 1,
#  'u': 2,
#  'i': 1,
#  'c': 1,
#  'k': 1,
#  'b': 1,
#  'r': 2,
#  'o': 4,
#  'w': 1,
#  'n': 1,
#  'f': 1,
#  'x': 1,
#  'j': 1,
#  'm': 1,
#  'p': 1,
#  's': 1,
#  'v': 1,
#  'l': 1,
#  'a': 1,
#  'z': 1,
#  'y': 1,
#  'd': 1,
#  'g': 1}

# %%
#using a dictionary in a for loop
#Python implements some very convenient handling
#for dictionary items with a for loop.
def print_hist(h):
    for c in h:
        print(c, h[c])
        
print_hist(histogram('dinosaur'))
#okay, that was nice...
#but maybe we can even do better...
# Out:
# d 1
# i 1
# n 1
# o 1
# s 1
# a 1
# u 1
# r 1

# %%
def print_hist(h):
    for key, value in h.items():
        print(key, value)
print_hist(histogram('dinosaur'))
# Out:
# d 1
# i 1
# n 1
# o 1
# s 1
# a 1
# u 1
# r 1

# %% [markdown]
# Reverse lookup
# Given a dictionary d and a key k, you can easily lookup the corresponding value.  This is called a lookup.
# But what if you have v and want any keys that map to v?
# One simple way:

# %%
def reverse_lookup(d,v):
    for k in d:
        if d[k] == v:
            return k
    raise LookupError()
    
h = histogram('aacaabbd')
reverse_lookup(h,2)
# Out:
# 'b'

# %%
#alternately, 
reverse_lookup(h, 6)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-24-e5922c13304a> in <module>
#       1 #alternately,
# ----> 2 reverse_lookup(h, 6)
#
# <ipython-input-23-f2aabb6cab92> in reverse_lookup(d, v)
#       3         if d[k] == v:
#       4             return k
# ----> 5     raise LookupError()
#       6
#       7 h = histogram('aacaabbd')
#
# LookupError:

# %% [markdown]
# # Dictionaries and lists.
#  You can have lists as the values of a dictionary, but not as the keys.  Lists in Python are unhashable.  For example:

# %%
t = [1,2]
d = {}
d['a'] = t #works okay.
d[t] = 'a' #doesn't work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-83610ee20b20> in <module>
#       2 d = {}
#       3 d['a'] = t #works okay.
# ----> 4 d[t] = 'a' #doesn't work
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# Then what does it mean to be hashable/unhashable?  What's a hash?
# A hash is a function that takes a value and returns an integer.  Dictionaries use these integers called hash values to store and lookup key-value pairs.
# Works fine if the keys are immutable, but harder if the keys are mutable like lists.
# When you create a key-value pair map in a Python dictionary, Python hashes the key and stores it in the corresponding integer location in memory.
# It's for this reason that lookups are so fast - if you look up a key value, Python hashes it and instantly knows where to look in memory - if there's a value there, it returns it, if there isn't a value there, it knows the key doesn't exist in the dictionary.

# %% [markdown]
# # Other uses for Dictionaries:  Memoing

# %% [markdown]
# Remember the fibonacci sequence code we had which was recursive?  It took a long time to run to find high-value terms of fibonacci sequence because it re-calculated terms inefficiently.
# But, using dictionaries to record calculated fibonacci sequence values, we can improve the run-time substantially!

# %%
known = {0:0, 1:1}

def fibonacci(n):
    if n in known:
        return known[n]

    new = fibonacci(n-1) + fibonacci(n-2)
    known[n] = new
    return new

fibonacci(36)
# Out:
# 14930352

# %%
#Compare with the original code from chapter 6.
def fibonacci(n):
    if n == 0:
        return 0
    elif  n == 1:
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)
fibonacci(36)
# Out:
# 14930352

# %% [markdown]
# # Global Variables
# Okay, that's all neat.  Now for a quick foray into a question I know some of you have asked before, about scope of variables in and out of functions (and will be relevant also in/out of objects).
#
# Note that the "known" variable above exists outside of the function.  This was necessary to have access to it in each and every instance of the function call.  (It could have been passed back and forth along with each call, but that is more complicated than just having it global).
#
# There are a few subtleties in global variable usage.

# %%
#One use is to make a boolean flag for verbose
#outputs.

verbose = True
def ex1():
    if verbose:
        print('Running ex1')
ex1()
# Out:
# Running ex1

# %%
#But if you try to reassign a global, 
#you might be surprised.
new_bool = False
def ex2():
    new_bool = True #need to make a change here
ex2()
new_bool
# Out:
# False

# %%
#You can see that global new_bool didn't change.  
#In the function, it creates a new local variable
#called new_bool and sets -that- to True.
#So how can we reassign the global?
new_bool = False
def ex2():
    global new_bool #This line makes it work!
    new_bool = True #need to make a change here
ex2()
new_bool

#NB: We got around it with "known" because we 
#aren't reassigning, we are using one of its
#built in abilities, making a key-value pair
#i.e. known[n] = new
#So, you can add/remove/replace elements of a global
#list or dictionary without this step,
#But if you want to reassign the variable,
#you have to declare it global like this.
# Out:
# True

# %% [markdown]
# Global handling is a little clunky and handled different in every language.  But in Python, if you stick to the approach above, you should be okay.

# %% [markdown]
# ## Exercises!

# %% [raw]
# Exercise 1
# Write a function that reads the words in words.txt and stores them as keys in a dictionary. It doesn’t matter what the values are. Then you can use the in operator as a fast way to check whether a string is in the dictionary.
# If you did Exercise 10 in Chapter 10, you can compare the speed of this implementation with the list in operator and the bisection search.

# %%
#To get you started:
import time
def make_word_dict():
    """Reads lines from a file and builds a dictionary"""
    t = {}
    fin = open('words.txt')
    for line in fin:
        word = line.strip()
        t[word]=1
        ## ENTER DICTIONARY ENTRY LINE HERE
    return t

def make_word_dict_list():
    t = []
    fin = open('words.txt')
    for line in fin:
        
        t.append(word)
d = make_word_dict()
t1 = time.time()
print('aardvark' in d)
t2 = time.time()
'zebra' in d
t3 = time.time()
print(t3 - t2, t2 - t1)
# Out:
# True
# 0.0 0.0

# %% [raw]
# Exercise 2
# Read the documentation of the dictionary method setdefault and use it to write a more concise version of invert_dict. Solution: http://thinkpython2.com/code/invert_dict.py.

# %%
def invert_dict(d):
    inverse - dict()
    for key in d:
        val = d[key]
        if val not in inverse:
            inverse[val] = [key]
        else:
            inverse[val].append(key)
    return inverse

# %% [raw]
# Exercise 3   Memoize the Ackermann function from Exercise 2 and see if memoization makes it possible to evaluate the function with bigger arguments. Hint: no. Solution: http://thinkpython2.com/code/ackermann_memo.py.

# %%
known = {0:0, 1:1}
#ran this in python tutor and saw procedure

def fibonacci(n):
    if n in known:
        return known[n]
    new = fibonacci(n-1) + fibonacci(n-2)
    known[n] = new
    return new

fibonacci(4)
# Out:
# 3

# %%
d={}
d[(0,0)]=1
d[(0,1)]=2

def ackermann(m,n):
    if type(m)!=int or m<0 or n<0 or type(n)!=int:
        print("error: Ackermann not defined for negative m.")
        return
    if m==0:
        d[(m,n)]=n+1
        return n+1
    elif n==0:
        d[(m,n)]=ackermann(m-1,1)
    else:
        d[(m,n)]=ackermann(m-1, ackermann(m,n-1))
    return d[(m,n)]

print(ackermann(3,6))
print(d)
# Out:
# 509
# {(0, 0): 1, (0, 1): 2, (1, 0): 2, (0, 2): 3, (1, 1): 3, (2, 0): 3, (0, 3): 4, (1, 2): 4, (0, 4): 5, (1, 3): 5, (2, 1): 5, (3, 0): 5, (0, 5): 6, (1, 4): 6, (0, 6): 7, (1, 5): 7, (2, 2): 7, (0, 7): 8, (1, 6): 8, (0, 8): 9, (1, 7): 9, (2, 3): 9, (0, 9): 10, (1, 8): 10, (0, 10): 11, (1, 9): 11, (2, 4): 11, (0, 11): 12, (1, 10): 12, (0, 12): 13, (1, 11): 13, (2, 5): 13, (3, 1): 13, (0, 13): 14, (1, 12): 14, (0, 14): 15, (1, 13): 15, (2, 6): 15, (0, 15): 16, (1, 14): 16, (0, 16): 17, (1, 15): 17, (2, 7): 17, (0, 17): 18, (1, 16): 18, (0, 18): 19, (1, 17): 19, (2, 8): 19, (0, 19): 20, (1, 18): 20, (0, 20): 21, (1, 19): 21, (2, 9): 21, (0, 21): 22, (1, 20): 22, (0, 22): 23, (1, 21): 23, (2, 10): 23, (0, 23): 24, (1, 22): 24, (0, 24): 25, (1, 23): 25, (2, 11): 25, (0, 25): 26, (1, 24): 26, (0, 26): 27, (1, 25): 27, (2, 12): 27, (0, 27): 28, (1, 26): 28, (0, 28): 29, (1, 27): 29, (2, 13): 29, (3, 2): 29, (0, 29): 30, (1, 28): 30, (0, 30): 31, (1, 29): 31, (2, 14): 31, (0, 31): 32, (1, 30): 32, (0, 32): 33, (1, 31): 33, (2, 15): 33, (0, 33): 34, (1, 32): 34, (0, 34): 35, (1, 33): 35, (2, 16): 35, (0, 35): 36, (1, 34): 36, (0, 36): 37, (1, 35): 37, (2, 17): 37, (0, 37): 38, (1, 36): 38, (0, 38): 39, (1, 37): 39, (2, 18): 39, (0, 39): 40, (1, 38): 40, (0, 40): 41, (1, 39): 41, (2, 19): 41, (0, 41): 42, (1, 40): 42, (0, 42): 43, (1, 41): 43, (2, 20): 43, (0, 43): 44, (1, 42): 44, (0, 44): 45, (1, 43): 45, (2, 21): 45, (0, 45): 46, (1, 44): 46, (0, 46): 47, (1, 45): 47, (2, 22): 47, (0, 47): 48, (1, 46): 48, (0, 48): 49, (1, 47): 49, (2, 23): 49, (0, 49): 50, (1, 48): 50, (0, 50): 51, (1, 49): 51, (2, 24): 51, (0, 51): 52, (1, 50): 52, (0, 52): 53, (1, 51): 53, (2, 25): 53, (0, 53): 54, (1, 52): 54, (0, 54): 55, (1, 53): 55, (2, 26): 55, (0, 55): 56, (1, 54): 56, (0, 56): 57, (1, 55): 57, (2, 27): 57, (0, 57): 58, (1, 56): 58, (0, 58): 59, (1, 57): 59, (2, 28): 59, (0, 59): 60, (1, 58): 60, (0, 60): 61, (1, 59): 61, (2, 29): 61, (3, 3): 61, (0, 61): 62, (1, 60): 62, (0, 62): 63, (1, 61): 63, (2, 30): 63, (0, 63): 64, (1, 62): 64, (0, 64): 65, (1, 63): 65, (2, 31): 65, (0, 65): 66, (1, 64): 66, (0, 66): 67, (1, 65): 67, (2, 32): 67, (0, 67): 68, (1, 66): 68, (0, 68): 69, (1, 67): 69, (2, 33): 69, (0, 69): 70, (1, 68): 70, (0, 70): 71, (1, 69): 71, (2, 34): 71, (0, 71): 72, (1, 70): 72, (0, 72): 73, (1, 71): 73, (2, 35): 73, (0, 73): 74, (1, 72): 74, (0, 74): 75, (1, 73): 75, (2, 36): 75, (0, 75): 76, (1, 74): 76, (0, 76): 77, (1, 75): 77, (2, 37): 77, (0, 77): 78, (1, 76): 78, (0, 78): 79, (1, 77): 79, (2, 38): 79, (0, 79): 80, (1, 78): 80, (0, 80): 81, (1, 79): 81, (2, 39): 81, (0, 81): 82, (1, 80): 82, (0, 82): 83, (1, 81): 83, (2, 40): 83, (0, 83): 84, (1, 82): 84, (0, 84): 85, (1, 83): 85, (2, 41): 85, (0, 85): 86, (1, 84): 86, (0, 86): 87, (1, 85): 87, (2, 42): 87, (0, 87): 88, (1, 86): 88, (0, 88): 89, (1, 87): 89, (2, 43): 89, (0, 89): 90, (1, 88): 90, (0, 90): 91, (1, 89): 91, (2, 44): 91, (0, 91): 92, (1, 90): 92, (0, 92): 93, (1, 91): 93, (2, 45): 93, (0, 93): 94, (1, 92): 94, (0, 94): 95, (1, 93): 95, (2, 46): 95, (0, 95): 96, (1, 94): 96, (0, 96): 97, (1, 95): 97, (2, 47): 97, (0, 97): 98, (1, 96): 98, (0, 98): 99, (1, 97): 99, (2, 48): 99, (0, 99): 100, (1, 98): 100, (0, 100): 101, (1, 99): 101, (2, 49): 101, (0, 101): 102, (1, 100): 102, (0, 102): 103, (1, 101): 103, (2, 50): 103, (0, 103): 104, (1, 102): 104, (0, 104): 105, (1, 103): 105, (2, 51): 105, (0, 105): 106, (1, 104): 106, (0, 106): 107, (1, 105): 107, (2, 52): 107, (0, 107): 108, (1, 106): 108, (0, 108): 109, (1, 107): 109, (2, 53): 109, (0, 109): 110, (1, 108): 110, (0, 110): 111, (1, 109): 111, (2, 54): 111, (0, 111): 112, (1, 110): 112, (0, 112): 113, (1, 111): 113, (2, 55): 113, (0, 113): 114, (1, 112): 114, (0, 114): 115, (1, 113): 115, (2, 56): 115, (0, 115): 116, (1, 114): 116, (0, 116): 117, (1, 115): 117, (2, 57): 117, (0, 117): 118, (1, 116): 118, (0, 118): 119, (1, 117): 119, (2, 58): 119, (0, 119): 120, (1, 118): 120, (0, 120): 121, (1, 119): 121, (2, 59): ...

# %% [raw]
# Exercise 4
# If you did Exercise 7 in chapter 10, you already have a function named has_duplicates that takes a list as a parameter and returns True if there is any object that appears more than once in the list.
# Use a dictionary to write a faster, simpler version of has_duplicates. Solution: http://thinkpython2.com/code/has_duplicates.py.

# %%
def has_duplicates_list(a):
    for j in range(len(a)):
        for i in range(len(a)-1-j):
            if a[j]==a[i+1]:
                return True
            
    return False

a=[1,2,4,5,6,13,2]

def has_duplicates_dict(a):
    global d
    d={}
    for element in a:
        if element in d:
            return True
        else:
            d[element]=1
        
    return False

t_f=has_duplicates_dict(list('walmart'))
        
print(d)
# Out:
# {'w': 1, 'a': 1, 'l': 1, 'm': 1}

# %%
from random import *

a=sample(range(0,10),4)
print(a)
a.extend(a[1:3])
print(a)
has_duplicates_dict(a)
# Out:
# [0, 9, 7, 8]
# [0, 9, 7, 8, 9, 7]
# True

# %%
from random import *

a=sample(range(0,1000000),1000)
a.extend(a[1:3])

from time import perf_counter
st1=perf_counter()
tf_dict=has_duplicates_dict(a)
stpl=perf_counter()
print("dictionary took",stpl-st1,"seconds and returned", tf_dict)

st2=perf_counter()
tf_list=has_duplicates_list(a)
stp2=perf_counter()
print("List took",stp2-st2,"seconds and returned", tf_list)

print(has_duplicates_dict(a))
# Out:
# dictionary took 0.0013577000001987471 seconds and returned True
# List took 0.00047979999999370193 seconds and returned True
# True

# %% [raw]
# Exercise 5
# Two words are “rotate pairs” if you can rotate one of them and get the other (see rotate_word in Exercise 5 of Chapter 8).
# Write a program that reads a wordlist and finds all the rotate pairs. Solution: http://thinkpython2.com/code/rotate_pairs.py.

# %%
def rotate_letter(s,shift):
    rotated=""
    for char in s:
        new_ord=(((ord(s)+shift)-97)%26)+97
        new_char=chr(new_ord)
        return new_char
    
def rotate_word(string, shift):
    rotated=""
    for s in string:
        new_s=rotate_letter(s,shift)
        rotated+=new_s
    return rotated

def make_dict():
    global t
    t = {}
    fin = open('words.txt')
    for line in fin:
        word = line.strip().lower()
        t[word]='word'
    return t
        
make_dict()
print(t['dog'])
        
print(rotate_letter('a',5))

print(rotate_word('melon',-10))

def rotate_pairs():
    t=make_dict()
    for key in t:
        for i in range(1,14):
            rotated_key=rotate_word(key,i)
            if rotated_key in t:
                print("These words are rotate_pairs",key,rotated_key)
# Out:
# word
# f
# cubed

# %%
                
rotate_pairs()
# Out:
# These words are rotate_pairs aah eel
# These words are rotate_pairs abet hila
# These words are rotate_pairs abjurer nowhere
# These words are rotate_pairs abo efs
# These words are rotate_pairs abo nob
# These words are rotate_pairs aby deb
# These words are rotate_pairs ache gink
# These words are rotate_pairs ad be
# These words are rotate_pairs ad eh
# These words are rotate_pairs ad lo
# These words are rotate_pairs add bee
# These words are rotate_pairs add ill
# These words are rotate_pairs add loo
# These words are rotate_pairs adder beefs
# These words are rotate_pairs adds beet
# These words are rotate_pairs ado fit
# These words are rotate_pairs ads bet
# These words are rotate_pairs ads fix
# These words are rotate_pairs adz fie
# These words are rotate_pairs aff inn
# These words are rotate_pairs aga eke
# These words are rotate_pairs ah bi
# These words are rotate_pairs ah el
# These words are rotate_pairs ah ho
# These words are rotate_pairs ah nu
# These words are rotate_pairs aha bib
# These words are rotate_pairs aha nun
# These words are rotate_pairs ahem holt
# These words are rotate_pairs ahull gnarr
# These words are rotate_pairs ai em
# These words are rotate_pairs ai go
# These words are rotate_pairs ai mu
# These words are rotate_pairs ail gor
# These words are rotate_pairs ails gory
# These words are rotate_pairs ain got
# These words are rotate_pairs air gox
# These words are rotate_pairs air mud
# These words are rotate_pairs ais goy
# These words are rotate_pairs alb doe
# These words are rotate_pairs ale jun
# These words are rotate_pairs alkyd epoch
# These words are rotate_pairs alp dos
# These words are rotate_pairs alt dow
# These words are rotate_pairs am my
# These words are rotate_pairs ambo myna
# These words are rotate_pairs amu cow
# These words are rotate_pairs an bo
# These words are rotate_pairs an er
# These words are rotate_pairs an na
# These words are rotate_pairs ana bob
# These words are rotate_pairs ana ere
# These words are rotate_pairs ana huh
# These words are rotate_pairs ani hup
# These words are rotate_pairs anil navy
# These words are rotate_pairs anna boob
# These words are rotate_pairs ant lye
# These words are rotate_pairs ant nag
# These words are rotate_pairs anteed bouffe
# These words are rotate_pairs ants bout
# These words are rotate_pairs ape lap
# These words are rotate_pairs aped fuji
# These words are rotate_pairs arf dui
# These words are rotate_pairs aril hyps
# These words are rotate_pairs ark dun
# These words are rotate_pairs arm dup
# These words are rotate_pairs ars jab
# These words are rotate_pairs as me
# These words are rotate_pairs ash met
# These words are rotate_pairs ask cum
# These words are rotate_pairs ask mew
# These words are rotate_pairs asp cur
# These words are rotate_pairs at ex
# These words are rotate_pairs at ha
# These words are rotate_pairs atma hath
# These words are rotate_pairs auk cwm
# These words are rotate_pairs avo fat
# These words are rotate_pairs avo nib
# These words are rotate_pairs aw mi
# These words are rotate_pairs awa mim
# These words are rotate_pairs awl mix
# These words are rotate_pairs awn ear
# These words are rotate_pairs axal dado
# These words are rotate_pairs axe dah
# These words are rotate_pairs axe lip
# These words are rotate_pairs ays gey
# These words are rotate_pairs azo fet
# These words are rotate_pairs azon fets
# These words are rotate_pairs ba on
# These words are rotate_pairs baa fee
# These words are rotate_pairs baal eddo
# These words are rotate_pairs baff jinn
# These words are rotate_pairs balk onyx
# These words are rotate_pairs ban fer
# These words are rotate_pairs banjo ferns
# These words are rotate_pairs bar one
# These words are rotate_pairs barf ones
# These words are rotate_pairs bas few
# These words are rotate_pairs bat jib
# These words are rotate_pairs batt jibb
# These words are rotate_pairs bay jig
# These words are rotate_pairs be eh
# These words are rotate_pairs be lo
# These words are rotate_pairs be or
# These words are rotate_pairs bed ilk
# These words are rotate_pairs bee ill
# These words are rotate_pairs bee loo
# These words are rotate_pairs beef loop
# These words are rotate_pairs been orra
# These words are rotate_pairs beer illy
# These words are rotate_pairs beg ort
# These words are rotate_pairs ben fir
# These words are rotate_pairs ben lox
# These words are rotate_pairs ben ora
# These words are rotate_pairs berg knap
# These words are rotate_pairs bet fix
# These words are rotate_pairs bi el
# These words are rotate_pairs bi ho
# These words are rotate_pairs bi nu
# These words are rotate_pairs bib nun
# These words are rotate_pairs biffs holly
# These words are rotate_pairs big nus
# These words are rotate_pairs bin hot
# These words are rotate_pairs bin ova
# These words are rotate_pairs bis hoy
# These words are rotate_pairs bo er
# These words are rotate_pairs bo na
# These words are rotate_pairs boa hug
# These words are rotate_pairs boas name
# These words are rotate_pairs bob ere
# These words are rotate_pairs bob huh
# These words are rotate_pairs bod erg
# These words are rotate_pairs bod nap
# These words are rotate_pairs bods nape
# These words are rotate_pairs boff hull
# These words are rotate_pairs bog hum
# These words are rotate_pairs bolls hurry
# These words are rotate_pairs bomb hush
# These words are rotate_pairs bombyx hushed
# These words are rotate_pairs boo err
# These words are rotate_pairs bop ers
# These words are rotate_pairs bop nab
# These words are rotate_pairs bos nae
# These words are rotate_pairs box era
# These words are rotate_pairs boy hue
# These words are rotate_pairs brie karn
# These words are rotate_pairs bub hah
# These words are rotate_pairs bub oho
# These words are rotate_pairs bud haj
# These words are rotate_pairs buff hall
# These words are rotate_pairs buffi hallo
# These words are rotate_pairs bug ham
# These words are rotate_pairs bulls harry
# These words are rotate_pairs bum has
# These words are rotate_pairs bun hat
# These words are rotate_pairs bun lex
# These words are rotate_pairs bus hay
# These words are rotate_pairs but led
# These words are rotate_pairs buts hazy
# These words are rotate_pairs butyl hazer
# These words are rotate_pairs buy hae
# These words are rotate_pairs buy lei
# These words are rotate_pairs by da
# These words are rotate_pairs by he
# These words are rotate_pairs by if
# These words are rotate_pairs by li
# These words are rotate_pairs bye dag
# These words are rotate_pairs byre khan
# These words are rotate_pairs bys hey
# These words are rotate_pairs byte lido
# These words are rotate_pairs calk kits
# These words are rotate_pairs cans kiva
# These words are rotate_pairs cap get
# These words are rotate_pairs capo gets
# These words are rotate_pairs caps ecru
# These words are rotate_pairs cede mono
# These words are rotate_pairs cedi mons
# These words are rotate_pairs cee egg
# These words are rotate_pairs cee moo
# These words are rotate_pairs ceil gimp
# These words are rotate_pairs chain ingot
# These words are rotate_pairs char dibs
# These words are rotate_pairs chat pung
# These words are rotate_pairs cheer jolly
# These words are rotate_pairs chef purs
# These words are rotate_pairs cloy forb
# These words are rotate_pairs cobb free
# These words are rotate_pairs col fro
# These words are rotate_pairs cold frog
# These words are rotate_pairs colt frow
# These words are rotate_pairs cord frug
# These words are rotate_pairs cot oaf
# These words are rotate_pairs coy oak
# These words are rotate_pairs craal penny
# These words are rotate_pairs crag pent
# These words are rotate_pairs crap fuds
# These words are rotate_pairs creel perry
# These words are rotate_pairs crib lark
# These words are rotate_pairs crop furs
# These words are rotate_pairs cry eta
# These words are rotate_pairs cry fub
# These words are rotate_pairs cub mel
# These words are rotate_pairs cubed melon
# These words are rotate_pairs cud men
# These words are rotate_pairs cum mew
# These words are rotate_pairs cuss ogee
# These words are rotate_pairs czar dabs
# These words are rotate_pairs da he
# These words are rotate_pairs da if
# These words are rotate_pairs da li
# These words are rotate_pairs dab khi
# These words are rotate_pairs daff linn
# These words are rotate_pairs dah lip
# These words are rotate_pairs dak lis
# These words are rotate_pairs danio herms
# These words are rotate_pairs dank hero
# These words are rotate_pairs dap het
# These words are rotate_pairs dash olds
# These words are rotate_pairs daw lie
# These words are rotate_pairs dawk lies
# These words are rotate_pairs dawn hear
# These words are rotate_pairs de ef
# These words are rotate_pairs de hi
# These words are rotate_pairs de no
# These words are rotate_pairs de op
# These words are rotate_pairs dee eff
# These words are rotate_pairs dee noo
# These words are rotate_pairs deed noon
# These words are rotate_pairs deer effs
# These words are rotate_pairs dei him
# These words are rotate_pairs dei nos
# These words are rotate_pairs dei opt
# These words are rotate_pairs del hip
# These words are rotate_pairs des eft
# These words are rotate_pairs dew nog
# These words are rotate_pairs dex noh
# These words are rotate_pairs dey hic
# These words are rotate_pairs dib pun
# These words are rotate_pairs did pup
# These words are rotate_pairs dido pupa
# These words are rotate_pairs didos pupae
# These words are rotate_pairs dig pus
# These words are rotate_pairs din ins
# These words are rotate_pairs din jot
# These words are rotate_pairs dip pub
# These words are rotate_pairs djin ions
# These words are rotate_pairs do it
# These words are rotate_pairs do pa
# These words are rotate_pairs dodo juju
# These words are rotate_pairs dodo papa
# These words are rotate_pairs doff parr
# These words are rotate_pairs dog pas
# These words are rotate_pairs dogs pase
# These words are rotate_pairs dol pax
# These words are rotate_pairs dols jury
# These words are rotate_pairs dolt grow
# These words are rotate_pairs dom jus
# These words are rotate_pairs dom pay
# These words are rotate_pairs don its
# These words are rotate_pairs don jut
# These words are rotate_pairs dor pad
# These words are rotate_pairs dory grub
# These words are rotate_pairs doxy grab
# These words are rotate_pairs drab gude
# These words are rotate_pairs drib mark
# These words are rotate_pairs drip guls
# These words are rotate_pairs drips octad
# These words are rotate_pairs dud eve
# These words are rotate_pairs dug jam
# These words are rotate_pairs dui oft
# These words are rotate_pairs duly nevi
# These words are rotate_pairs dye fag
# These words are rotate_pairs eat mib
# These words are rotate_pairs eats pled
# These words are rotate_pairs eau oke
# These words are rotate_pairs eaux okeh
# These words are rotate_pairs ebbs roof
# These words are rotate_pairs eche kink
# These words are rotate_pairs eches kinky
# These words are rotate_pairs ef hi
# These words are rotate_pairs ef no
# These words are rotate_pairs ef op
# These words are rotate_pairs eff noo
# These words are rotate_pairs efs nob
# These words are rotate_pairs egad moil
# These words are rotate_pairs egg moo
# These words are rotate_pairs ego mow
# These words are rotate_pairs eh lo
# These words are rotate_pairs eh or
# These words are rotate_pairs el ho
# These words are rotate_pairs el nu
# These words are rotate_pairs eld hog
# These words are rotate_pairs elds numb
# These words are rotate_pairs elk nut
# These words are rotate_pairs elm hop
# These words are rotate_pairs els gnu
# These words are rotate_pairs els nub
# These words are rotate_pairs em go
# These words are rotate_pairs em mu
# These words are rotate_pairs em ow
# These words are rotate_pairs eme mum
# These words are rotate_pairs emu owe
# These words are rotate_pairs en ox
# These words are rotate_pairs end foe
# These words are rotate_pairs eng foh
# These words are rotate_pairs eng irk
# These words are rotate_pairs eng rat
# These words are rotate_pairs envy rail
# These words are rotate_pairs er na
# These words are rotate_pairs er re
# These words are rotate_pairs ere huh
# These words are rotate_pairs erg nap
# These words are rotate_pairs erg ret
# These words are rotate_pairs erne rear
# These words are rotate_pairs err ree
# These words are rotate_pairs errs reef
# These words are rotate_pairs ers nab
# These words are rotate_pairs ers ref
# These words are rotate_pairs es ma
# These words are rotate_pairs eses mama
# These words are rotate_pairs et la
# These words are rotate_pairs et od
# These words are rotate_pairs et pe
# These words are rotate_pairs eta fub
# These words are rotate_pairs etch pens
# These words are rotate_pairs eth pes
# These words are rotate_pairs etui odes
# These words are rotate_pairs ewe mem
# These words are rotate_pairs ex ha
# These words are rotate_pairs ex oh
# These words are rotate_pairs ex pi
# These words are rotate_pairs eye gag
# These words are rotate_pairs fa id
# These words are rotate_pairs fad nil
# These words are rotate_pairs fang jerk
# These words are rotate_pairs fas jew
# These words are rotate_pairs fat nib
# These words are rotate_pairs feed poon
# These words are rotate_pairs feet pood
# These words are rotate_pairs fen pox
# These words are rotate_pairs fet pod
# These words are rotate_pairs fey poi
# These words are rotate_pairs fib run
# These words are rotate_pairs fibs rune
# These words are rotate_pairs fido knit
# These words are rotate_pairs figs ruse
# These words are rotate_pairs fills lorry
# These words are rotate_pairs fils lory
# These words are rotate_pairs fin lot
# These words are rotate_pairs fir lox
# These words are rotate_pairs fir ora
# These words are rotate_pairs firs rude
# These words are rotate_pairs fit orc
# These words are rotate_pairs fizz knee
# These words are rotate_pairs fizzy kneed
# These words are rotate_pairs flap sync
# These words are rotate_pairs flu oud
# These words are rotate_pairs foam lugs
# These words are rotate_pairs fob ire
# These words are rotate_pairs fob ran
# These words are rotate_pairs fog lum
# These words are rotate_pairs fog ras
# These words are rotate_pairs fogs rase
# These words are rotate_pairs foh irk
# These words are rotate_pairs foh rat
# These words are rotate_pairs fohn lunt
# These words are rotate_pairs folk iron
# These words are rotate_pairs fon pyx
# These words are rotate_pairs fons raze
# These words are rotate_pairs fop oxy
# These words are rotate_pairs for lux
# These words are rotate_pairs for rad
# These words are rotate_pairs fou pye
# These words are rotate_pairs fou rag
# These words are rotate_pairs fox raj
# These words are rotate_pairs foys pyic
# These words are rotate_pairs foys rake
# These words are rotate_pairs frag sent
# These words are rotate_pairs frere serer
# These words are rotate_pairs fry sel
# These words are rotate_pairs fud pen
# These words are rotate_pairs fug lam
# These words are rotate_pairs fuji pets
# These words are rotate_pairs fumy lase
# These words are rotate_pairs fun lat
# These words are rotate_pairs fur lax
# These words are rotate_pairs fur she
# These words are rotate_pairs fusion layout
# These words are rotate_pairs gab kef
# These words are rotate_pairs gad oil
# These words are rotate_pairs gaen keir
# These words are rotate_pairs gal kep
# These words are rotate_pairs gale kepi
# These words are rotate_pairs ganja kerne
# These words are rotate_pairs gassy smeek
# These words are rotate_pairs gat kex
# These words are rotate_pairs gel kip
# These words are rotate_pairs gel try
# These words are rotate_pairs ghat tung
# These words are rotate_pairs gib sun
# These words are rotate_pairs gid sup
# These words are rotate_pairs gids supe
# These words are rotate_pairs gift surf
# These words are rotate_pairs gig mom
# These words are rotate_pairs gin mot
# These words are rotate_pairs ginny motte
# These words are rotate_pairs gip pry
# These words are rotate_pairs gip sub
# These words are rotate_pairs gird pram
# These words are rotate_pairs girl prau
# These words are rotate_pairs glib jole
# These words are rotate_pairs gnar hobs
# These words are rotate_pairs gnat tang
# These words are rotate_pairs gnu nub
# These words are rotate_pairs go mu
# These words are rotate_pairs go ow
# These words are rotate_pairs goa mug
# These words are rotate_pairs goad samp
# These words are rotate_pairs goas same
# These words are rotate_pairs gobs sane
# These words are rotate_pairs goby sank
# These words are rotate_pairs god owl
# These words are rotate_pairs god sap
# These words are rotate_pairs golem murks
# These words are rotate_pairs golly murre
# These words are rotate_pairs gor sad
# These words are rotate_pairs gowk owes
# These words are rotate_pairs gox mud
# These words are rotate_pairs goys sake
# These words are rotate_pairs green terra
# These words are rotate_pairs guff mall
# These words are rotate_pairs gul mar
# These words are rotate_pairs gul thy
# These words are rotate_pairs gulf marl
# These words are rotate_pairs gulfs marly
# These words are rotate_pairs gulls marry
# These words are rotate_pairs gum mas
# These words are rotate_pairs gummy masse
# These words are rotate_pairs gun mat
# These words are rotate_pairs gunny matte
# These words are rotate_pairs guts mazy
# These words are rotate_pairs guy mae
# These words are rotate_pairs gym sky
# These words are rotate_pairs ha oh
# These words are rotate_pairs ha pi
# These words are rotate_pairs ha un
# These words are rotate_pairs hade slop
# These words are rotate_pairs hae lei
# These words are rotate_pairs haes pima
# These words are rotate_pairs hag lek
# These words are rotate_pairs hah oho
# These words are rotate_pairs hah pip
# These words are rotate_pairs haji slut
# These words are rotate_pairs ham piu
# These words are rotate_pairs hap let
# These words are rotate_pairs hap pix
# These words are rotate_pairs hark levo
# These words are rotate_pairs has pia
# These words are rotate_pairs hat lex
# These words are rotate_pairs hats sled
# These words are rotate_pairs haw lea
# These words are rotate_pairs haw pie
# These words are rotate_pairs hawk pies
# These words are rotate_pairs hay pig
# These words are rotate_pairs he if
# These words are rotate_pairs he li
# These words are rotate_pairs heil limp
# These words are rotate_pairs hem row
# These words are rotate_pairs hen spy
# These words are rotate_pairs hep lit
# These words are rotate_pairs hep spa
# These words are rotate_pairs her ifs
# These words are rotate_pairs her rob
# These words are rotate_pairs hern urea
# These words are rotate_pairs hes roc
# These words are rotate_pairs het rod
# These words are rotate_pairs hew old
# These words are rotate_pairs hewn liar
# These words are rotate_pairs hex lib
# These words are rotate_pairs hex ole
# These words are rotate_pairs hi no
# These words are rotate_pairs hi op
# These words are rotate_pairs hid tup
# These words are rotate_pairs hide stop
# These words are rotate_pairs him nos
# These words are rotate_pairs him opt
# These words are rotate_pairs hin not
# These words are rotate_pairs hin sty
# These words are rotate_pairs hint stye
# These words are rotate_pairs hints styed
# These words are rotate_pairs hip tub
# These words are rotate_pairs hips tube
# These words are rotate_pairs ho nu
# These words are rotate_pairs ho ta
# These words are rotate_pairs hob tan
# These words are rotate_pairs hod tap
# These words are rotate_pairs hods tape
# These words are rotate_pairs hog tas
# These words are rotate_pairs hogg tass
# These words are rotate_pairs hoggs tasse
# These words are rotate_pairs hop tab
# These words are rotate_pairs hot ova
# These words are rotate_pairs hotel ovals
# These words are rotate_pairs hoys take
# These words are rotate_pairs hub obi
# These words are rotate_pairs huff repp
# These words are rotate_pairs huic naoi
# These words are rotate_pairs hun rex
# These words are rotate_pairs hut red
# These words are rotate_pairs hymn nest
# These words are rotate_pairs hyp jar
# These words are rotate_pairs ibex pile
# These words are rotate_pairs ice keg
# These words are rotate_pairs icy kea
# These words are rotate_pairs id to
# These words are rotate_pairs id up
# These words are rotate_pairs idem snow
# These words are rotate_pairs ids jet
# These words are rotate_pairs ids nix
# These words are rotate_pairs ids tod
# These words are rotate_pairs if li
# These words are rotate_pairs ifs rob
# These words are rotate_pairs ilex rung
# These words are rotate_pairs ilk rut
# These words are rotate_pairs ill loo
# These words are rotate_pairs imp kor
# These words are rotate_pairs in jo
# These words are rotate_pairs ink pur
# These words are rotate_pairs inkier purply
# These words are rotate_pairs inks jolt
# These words are rotate_pairs ins jot
# These words are rotate_pairs ion out
# These words are rotate_pairs ire ran
# These words are rotate_pairs irk rat
# These words are rotate_pairs irk vex
# These words are rotate_pairs is oy
# These words are rotate_pairs it pa
# These words are rotate_pairs itch tens
# These words are rotate_pairs its jut
# These words are rotate_pairs its ted
# These words are rotate_pairs ivy obe
# These words are rotate_pairs izar jabs
# These words are rotate_pairs jay rig
# These words are rotate_pairs jee too
# These words are rotate_pairs jeed toon
# These words are rotate_pairs jehu tore
# These words are rotate_pairs jerky snath
# These words are rotate_pairs jet nix
# These words are rotate_pairs jet tod
# These words are rotate_pairs jeu toe
# These words are rotate_pairs jew tog
# These words are rotate_pairs jib poh
# These words are rotate_pairs jiff poll
# These words are rotate_pairs jiffs polly
# These words are rotate_pairs jimmy posse
# These words are rotate_pairs jin ons
# These words are rotate_pairs jin pot
# These words are rotate_pairs jinni potto
# These words are rotate_pairs jinns potty
# These words are rotate_pairs job van
# These words are rotate_pairs jobs vane
# These words are rotate_pairs joey puke
# These words are rotate_pairs jog vas
# These words are rotate_pairs jogs vase
# These words are rotate_pairs john punt
# These words are rotate_pairs johns punty
# These words are rotate_pairs jug pam
# These words are rotate_pairs juju papa
# These words are rotate_pairs jun pat
# These words are rotate_pairs jun wha
# These words are rotate_pairs jura when
# These words are rotate_pairs jus pay
# These words are rotate_pairs jut ted
# These words are rotate_pairs ka oe
# These words are rotate_pairs ka si
# These words are rotate_pairs kae sim
# These words are rotate_pairs kaes sima
# These words are rotate_pairs kat sib
# These words are rotate_pairs khan spiv
# These words are rotate_pairs kip try
# These words are rotate_pairs knar lobs
# These words are rotate_pairs knur ruby
# These words are rotate_pairs koa ose
# These words are rotate_pairs koas wame
# These words are rotate_pairs kop wab
# These words are rotate_pairs kor wad
# These words are rotate_pairs kors wade
# These words are rotate_pairs kos wae
# These words are rotate_pairs la od
# These words are rotate_pairs la pe
# These words are rotate_pairs la sh
# These words are rotate_pairs la ti
# These words are rotate_pairs lab ode
# These words are rotate_pairs lac peg
# These words are rotate_pairs lad til
# These words are rotate_pairs lallan pepper
# These words are rotate_pairs lane peri
# These words are rotate_pairs lane shul
# These words are rotate_pairs lang perk
# These words are rotate_pairs lang shun
# These words are rotate_pairs lap ods
# These words are rotate_pairs lap pet
# These words are rotate_pairs lar shy
# These words are rotate_pairs las pew
# These words are rotate_pairs later shaly
# These words are rotate_pairs latex shale
# These words are rotate_pairs law pea
# These words are rotate_pairs law tie
# These words are rotate_pairs lawn pear
# These words are rotate_pairs lax she
# These words are rotate_pairs lea pie
# These words are rotate_pairs lean pier
# These words are rotate_pairs led von
# These words are rotate_pairs let pix
# These words are rotate_pairs leu voe
# These words are rotate_pairs ley pic
# These words are rotate_pairs li xu
# These words are rotate_pairs lib ole
# These words are rotate_pairs lie urn
# These words are rotate_pairs limy rose
# These words are rotate_pairs lin rot
# These words are rotate_pairs ling spun
# These words are rotate_pairs link spur
# These words are rotate_pairs linum rotas
# These words are rotate_pairs liny rote
# These words are rotate_pairs lion rout
# These words are rotate_pairs lit spa
# These words are rotate_pairs lo or
# These words are rotate_pairs loaf twin
# These words are rotate_pairs loam rugs
# These words are rotate_pairs lob ore
# These words are rotate_pairs loch ruin
# These words are rotate_pairs log rum
# These words are rotate_pairs log two
# These words are rotate_pairs loop psst
# These words are rotate_pairs lop ors
# These words are rotate_pairs lowe ruck
# These words are rotate_pairs lox ora
# These words are rotate_pairs luau raga
# These words are rotate_pairs luffs rally
# These words are rotate_pairs lug ram
# These words are rotate_pairs lum ras
# These words are rotate_pairs luna pyre
# These words are rotate_pairs luny rate
# These words are rotate_pairs lutea pyxie
# These words are rotate_pairs lux rad
# These words are rotate_pairs lye nag
# These words are rotate_pairs manful thumbs
# These words are rotate_pairs mar thy
# These words are rotate_pairs may oca
# These words are rotate_pairs me wo
# These words are rotate_pairs meet wood
# These words are rotate_pairs mem wow
# These words are rotate_pairs mho nip
# These words are rotate_pairs mho wry
# These words are rotate_pairs mi so
# These words are rotate_pairs mid yup
# These words are rotate_pairs mills sorry
# These words are rotate_pairs milt plow
# These words are rotate_pairs mim sos
# These words are rotate_pairs mir sox
# These words are rotate_pairs mis soy
# These words are rotate_pairs mix sod
# These words are rotate_pairs moa yam
# These words are rotate_pairs mocha suing
# These words are rotate_pairs mod yap
# These words are rotate_pairs mog sum
# These words are rotate_pairs mol pro
# These words are rotate_pairs mola prod
# These words are rotate_pairs molas surgy
# These words are rotate_pairs mold prog
# These words are rotate_pairs molt prow
# These words are rotate_pairs moly sure
# These words are rotate_pairs mom yay
# These words are rotate_pairs mott yaff
# These words are rotate_pairs mu ow
# These words are rotate_pairs mu we
# These words are rotate_pairs much sain
# These words are rotate_pairs mud wen
# These words are rotate_pairs muff sall
# These words are rotate_pairs muffs sally
# These words are rotate_pairs mulch sarin
# These words are rotate_pairs mule sark
# These words are rotate_pairs mumm sass
# These words are rotate_pairs mumms sassy
# These words are rotate_pairs mun sat
# These words are rotate_pairs munch satin
# These words are rotate_pairs mus say
# These words are rotate_pairs mut wed
# These words are rotate_pairs muumuu weewee
# These words are rotate_pairs na re
# These words are rotate_pairs na an
# These words are rotate_pairs nab ref
# These words are rotate_pairs nae rei
# These words are rotate_pairs nae vim
# These words are rotate_pairs nag ant
# These words are rotate_pairs nap ret
# These words are rotate_pairs navy anil
# These words are rotate_pairs nay rec
# These words are rotate_pairs nee off
# These words are rotate_pairs nib avo
# These words are rotate_pairs nil tor
# These words are rotate_pairs nil ups
# These words are rotate_pairs nill torr
# These words are rotate_pairs nils tory
# These words are rotate_pairs nip wry
# These words are rotate_pairs nisi toyo
# These words are rotate_pairs nix tod
# These words are rotate_pairs no op
# These words are rotate_pairs nob abo
# These words are rotate_pairs nod ope
# These words are rotate_pairs nod zap
# These words are rotate_pairs noggs tummy
# These words are rotate_pairs noh tun
# These words are rotate_pairs nome tusk
# These words are rotate_pairs nor ops
# These words are rotate_pairs nor tux
# These words are rotate_pairs nos opt
# These words are rotate_pairs not sty
# These words are rotate_pairs nowhere abjurer
# These words are rotate_pairs nth yes
# These words are rotate_pairs nu ta
# These words are rotate_pairs nu ah
# These words are rotate_pairs nulls tarry
# These words are rotate_pairs nun tat
# These words are rotate_pairs nun aha
# These words are rotate_pairs nutty tazze
# These words are rotate_pairs oaf win
# These words are rotate_pairs oafs ugly
# These words are rotate_pairs oak wis
# These words are rotate_pairs oar wiz
# These words are rotate_pairs oat sex
# These words are rotate_pairs od pe
# These words are rotate_pairs od sh
# These words are rotate_pairs od ti
# These words are rotate_pairs odd pee
# These words are rotate_pairs odd shh
# These words are rotate_pairs odd zoo
# These words are rotate_pairs odor peps
# These words are rotate_pairs ods pet
# These words are rotate_pairs ods ape
# These words are rotate_pairs oe si
# These words are rotate_pairs of ar
# These words are rotate_pairs oft arf
# These words are rotate_pairs oh pi
# These words are rotate_pairs oh un
# These words are rotate_pairs oh at
# These words are rotate_pairs ohm pin
# These words are rotate_pairs ohm uns
# These words are rotate_pairs ohms pint
# These words are rotate_pairs oho pip
# These words are rotate_pairs oho bub
# These words are rotate_pairs ohs pit
# These words are rotate_pairs ohs ate
# These words are rotate_pairs oka yuk
# These words are rotate_pairs okeh soil
# These words are rotate_pairs olla rood
# These words are rotate_pairs om us
# These words are rotate_pairs om ay
# These words are rotate_pairs oms aye
# These words are rotate_pairs on ut
# These words are rotate_pairs on ba
# These words are rotate_pairs one sri
# These words are rotate_pairs one bar
# These words are rotate_pairs ones barf
# These words are rotate_pairs ons pot
# These words are rotate_pairs onyx balk
# These words are rotate_pairs opal step
# These words are rotate_pairs ope zap
# These words are rotate_pairs open stir
# These words are rotate_pairs ops tux
# These words are rotate_pairs or ad
# These words are rotate_pairs or be
# These words are rotate_pairs ora ben
# These words are rotate_pairs orb rue
# These words are rotate_pairs orc ado
# These words are rotate_pairs ordo twit
# These words are rotate_pairs orra been
# These words are rotate_pairs ort beg
# These words are rotate_pairs os ae
# These words are rotate_pairs oud yen
# These words are rotate_pairs ova bin
# These words are rotate_pairs ow we
# These words are rotate_pairs ow ai
# These words are rotate_pairs owl sap
# These words are rotate_pairs owl wet
# These words are rotate_pairs oxim udos
# These words are rotate_pairs oxter vealy
# These words are rotate_pairs pa xi
# These words are rotate_pairs pac teg
# These words are rotate_pairs pah who
# These words are rotate_pairs paid alto
# These words are rotate_pairs pap ala
# These words are rotate_pairs par why
# These words are rotate_pairs pas tew
# These words are rotate_pairs pat wha
# These words are rotate_pairs pat ale
# These words are rotate_pairs path ales
# These words are rotate_pairs paw tea
# These words are rotate_pairs pawn tear
# These words are rotate_pairs pe sh
# These words are rotate_pairs pe ti
# These words are rotate_pairs pea tie
# These words are rotate_pairs pean tier
# These words are rotate_pairs pecan tiger
# These words are rotate_pairs pee shh
# These words are rotate_pairs pee zoo
# These words are rotate_pairs peed zoon
# These words are rotate_pairs pele tipi
# These words are rotate_pairs pelt show
# These words are rotate_pairs penny craal
# These words are rotate_pairs pent crag
# These words are rotate_pairs pep tit
# These words are rotate_pairs pepo tits
# These words are rotate_pairs peri shul
# These words are rotate_pairs perk shun
# These words are rotate_pairs perry creel
# These words are rotate_pairs pet ape
# These words are rotate_pairs pets aped
# These words are rotate_pairs phew wold
# These words are rotate_pairs phi wop
# These words are rotate_pairs pi un
# These words are rotate_pairs pi at
# These words are rotate_pairs pia bum
# These words are rotate_pairs pig bus
# These words are rotate_pairs pily slob
# These words are rotate_pairs pin uns
# These words are rotate_pairs piny vote
# These words are rotate_pairs pip bub
# These words are rotate_pairs pit ate
# These words are rotate_pairs pith ates
# These words are rotate_pairs piu bug
# These words are rotate_pairs pixy slab
# These words are rotate_pairs ploy sorb
# These words are rotate_pairs ply sob
# These words are rotate_pairs pod azo
# These words are rotate_pairs pogy bask
# These words are rotate_pairs poh bat
# These words are rotate_pairs pops babe
# These words are rotate_pairs prex wyle
# These words are rotate_pairs prex yang
# These words are rotate_pairs primero sulphur
# These words are rotate_pairs proa surd
# These words are rotate_pairs pry sub
# These words are rotate_pairs pry yah
# These words are rotate_pairs psst beef
# These words are rotate_pairs pull typp
# These words are rotate_pairs pulpy varve
# These words are rotate_pairs puls vary
# These words are rotate_pairs pun vat
# These words are rotate_pairs puna tyre
# These words are rotate_pairs pung chat
# These words are rotate_pairs punk tyro
# These words are rotate_pairs pup vav
# These words are rotate_pairs purs chef
# These words are rotate_pairs put zed
# These words are rotate_pairs pya veg
# These words are rotate_pairs pye rag
# These words are rotate_pairs pyic rake
# These words are rotate_pairs qua wag
# These words are rotate_pairs quay wage
# These words are rotate_pairs quey wake
# These words are rotate_pairs rads clod
# These words are rotate_pairs rah zip
# These words are rotate_pairs rail envy
# These words are rotate_pairs rap vet
# These words are rotate_pairs rape clap
# These words are rotate_pairs raphe clasp
# These words are rotate_pairs raps clad
# These words are rotate_pairs rat vex
# These words are rotate_pairs rat eng
# These words are rotate_pairs ratan vexer
# These words are rotate_pairs ray zig
# These words are rotate_pairs re an
# These words are rotate_pairs re bo
# These words are rotate_pairs re er
# These words are rotate_pairs rear erne
# These words are rotate_pairs redo bony
# These words are rotate_pairs ree boo
# These words are rotate_pairs ree err
# These words are rotate_pairs reed boon
# These words are rotate_pairs reef errs
# These words are rotate_pairs ref bop
# These words are rotate_pairs ref ers
# These words are rotate_pairs rei vim
# These words are rotate_pairs rei bos
# These words are rotate_pairs rem bow
# These words are rotate_pairs rep any
# These words are rotate_pairs ret bod
# These words are rotate_pairs ret erg
# These words are rotate_pairs rev ane
# These words are rotate_pairs rho sip
# These words are rotate_pairs rib ark
# These words are rotate_pairs rib dun
# These words are rotate_pairs ribs dune
# These words are rotate_pairs rid arm
# These words are rotate_pairs rid dup
# These words are rotate_pairs rids dupe
# These words are rotate_pairs riff durr
# These words are rotate_pairs rip dub
# These words are rotate_pairs river arena
# These words are rotate_pairs road damp
# These words are rotate_pairs rod dap
# These words are rotate_pairs roof ebbs
# These words are rotate_pairs rub bel
# These words are rotate_pairs ruddy benni
# These words are rotate_pairs rum two
# These words are rotate_pairs rut bed
# These words are rotate_pairs rye tag
# These words are rotate_pairs rye bio
# These words are rotate_pairs sad ail
# These words are rotate_pairs sae aim
# These words are rotate_pairs sag ems
# These words are rotate_pairs sal ait
# These words are rotate_pairs salp wept
# These words are rotate_pairs sap wet
# These words are rotate_pairs sawn wear
# These words are rotate_pairs sax web
# These words are rotate_pairs sea ami
# These words are rotate_pairs seas amia
# These words are rotate_pairs sec wig
# These words are rotate_pairs secco commy
# These words are rotate_pairs see coo
# These words are rotate_pairs seed coon
# These words are rotate_pairs sei cos
# These words are rotate_pairs sel fry
# These words are rotate_pairs semi cows
# These words are rotate_pairs sen cox
# These words are rotate_pairs sent frag
# These words are rotate_pairs ser cob
# These words are rotate_pairs sera wive
# These words are rotate_pairs serer frere
# These words are rotate_pairs set cod
# These words are rotate_pairs setal ambit
# These words are rotate_pairs sew cog
# These words are rotate_pairs sewed cogon
# These words are rotate_pairs sh ti
# These words are rotate_pairs sh et
# These words are rotate_pairs she fur
# These words are rotate_pairs sheer tiffs
# These words are rotate_pairs shh zoo
# These words are rotate_pairs shog etas
# These words are rotate_pairs shute credo
# These words are rotate_pairs sic uke
# These words are rotate_pairs silk brut
# These words are rotate_pairs sims aqua
# These words are rotate_pairs sir bra
# These words are rotate_pairs sire bran
# These words are rotate_pairs six yod
# These words are rotate_pairs size brin
# These words are rotate_pairs skua asci
# These words are rotate_pairs slag unci
# These words are rotate_pairs slam unco
# These words are rotate_pairs sleep bunny
# These words are rotate_pairs slip bury
# These words are rotate_pairs smog eyas
# These words are rotate_pairs sneer toffs
# These words are rotate_pairs so aw
# These words are rotate_pairs sod awl
# These words are rotate_pairs soil eaux
# These words are rotate_pairs sos awa
# These words are rotate_pairs sow awe
# These words are rotate_pairs spat dale
# These words are rotate_pairs spic byrl
# These words are rotate_pairs spit date
# These words are rotate_pairs spits dated
# These words are rotate_pairs spiv byre
# These words are rotate_pairs splits dawted
# These words are rotate_pairs spot daze
# These words are rotate_pairs spots dazed
# These words are rotate_pairs sri bar
# These words are rotate_pairs sris barb
# These words are rotate_pairs star tubs
# These words are rotate_pairs steeds tuffet
# These words are rotate_pairs steer tuffs
# These words are rotate_pairs stun defy
# These words are rotate_pairs sub yah
# These words are rotate_pairs sue yak
# These words are rotate_pairs sulk acts
# These words are rotate_pairs swop wast
# These words are rotate_pairs syn yet
# These words are rotate_pairs sync yeti
# These words are rotate_pairs sync flap
# These words are rotate_pairs ta ah
# These words are rotate_pairs ta bi
# These words are rotate_pairs ta el
# These words are rotate_pairs tab elm
# These words are rotate_pairs tag bio
# These words are rotate_pairs tahr ahoy
# These words are rotate_pairs talk bits
# These words are rotate_pairs tall bitt
# These words are rotate_pairs tang gnat
# These words are rotate_pairs tas eld
# These words are rotate_pairs task bias
# These words are rotate_pairs tat aha
# These words are rotate_pairs tat bib
# These words are rotate_pairs tau elf
# These words are rotate_pairs tav bid
# These words are rotate_pairs ted don
# These words are rotate_pairs tee all
# These words are rotate_pairs teloi whorl
# These words are rotate_pairs tenet alula
# These words are rotate_pairs terra green
# These words are rotate_pairs tew dog
# These words are rotate_pairs then espy
# These words are rotate_pairs tho dry
# These words are rotate_pairs thy gul
# These words are rotate_pairs ti et
# These words are rotate_pairs timer aptly
# These words are rotate_pairs tins fuze
# These words are rotate_pairs tip cry
# These words are rotate_pairs tip eta
# These words are rotate_pairs tip fub
# These words are rotate_pairs to up
# These words are rotate_pairs to fa
# These words are rotate_pairs tog fas
# These words are rotate_pairs tom fay
# These words are rotate_pairs ton upo
# These words are rotate_pairs tons faze
# These words are rotate_pairs tor ups
# These words are rotate_pairs tor fad
# These words are rotate_pairs torc fado
# These words are rotate_pairs tors fade
# These words are rotate_pairs torus fadge
# These words are rotate_pairs tot ava
# These words are rotate_pairs touch fagot
# These words are rotate_pairs tout dyed
# These words are rotate_pairs toys fake
# These words are rotate_pairs trek cant
# These words are rotate_pairs trig carp
# These words are rotate_pairs try gel
# These words are rotate_pairs tsars baiza
# These words are rotate_pairs tsk bas
# These words are rotate_pairs tsk few
# These words are rotate_pairs tub del
# These words are rotate_pairs tui des
# These words are rotate_pairs tui eft
# These words are rotate_pairs tun dex
# These words are rotate_pairs tung ghat
# These words are rotate_pairs tut aba
# These words are rotate_pairs typy vara
# These words are rotate_pairs ugh cop
# These words are rotate_pairs umps gybe
# These words are rotate_pairs un at
# These words are rotate_pairs un ex
# These words are rotate_pairs un ha
# These words are rotate_pairs up fa
# These words are rotate_pairs ups fad
# These words are rotate_pairs urd dam
# These words are rotate_pairs urea hern
# These words are rotate_pairs uredo ebony
# These words are rotate_pairs urn daw
# These words are rotate_pairs us ay
# These words are rotate_pairs use cam
# These words are rotate_pairs ut ba
# These words are rotate_pairs uta bah
# These words are rotate_pairs uts fed
# These words are rotate_pairs vans diva
# These words are rotate_pairs vat dib
# These words are rotate_pairs vats gled
# These words are rotate_pairs vav did
# These words are rotate_pairs vaw die
# These words are rotate_pairs vex eng
# These words are rotate_pairs vex foh
# These words are rotate_pairs vex irk
# These words are rotate_pairs via bog
# These words are rotate_pairs via hum
# These words are rotate_pairs vie ern
# These words are rotate_pairs vim bos
# These words are rotate_pairs vin bot
# These words are rotate_pairs viola bourg
# These words are rotate_pairs vis boy
# These words are rotate_pairs vis hue
# These words are rotate_pairs von but
# These words are rotate_pairs vox bud
# These words are rotate_pairs vox haj
# These words are rotate_pairs wad imp
# These words are rotate_pairs we ai
# These words are rotate_pairs we em
# These words are rotate_pairs we go
# These words are rotate_pairs weal emit
# These words are rotate_pairs wee goo
# These words are rotate_pairs weed goon
# These words are rotate_pairs weet good
# These words are rotate_pairs wen air
# These words are rotate_pairs wen gox
# These words are rotate_pairs were gobo
# These words are rotate_pairs wet god
# These words are rotate_pairs wha ale
# These words are rotate_pairs wha jun
# These words are rotate_pairs whee doll
# These words are rotate_pairs wheel dolls
# These words are rotate_pairs when jura
# These words are rotate_pairs whew grog
# These words are rotate_pairs whir dopy
# These words are rotate_pairs whit dopa
# These words are rotate_pairs wich coin
# These words are rotate_pairs wile cork
# These words are rotate_pairs wiles corky
# These words are rotate_pairs wily core
# These words are rotate_pairs win cot
# These words are rotate_pairs winy cote
# These words are rotate_pairs wis coy
# These words are rotate_pairs wit coz
# These words are rotate_pairs wits cozy
# These words are rotate_pairs wiver frena
# These words are rotate_pairs wo as
# These words are rotate_pairs wolf curl
# These words are rotate_pairs wolfs curly
# These words are rotate_pairs wombs cushy
# These words are rotate_pairs won cut
# These words are rotate_pairs woo ass
# These words are rotate_pairs wow ewe
# These words are rotate_pairs wyle yang
# These words are rotate_pairs xeric gnarl
# These words are rotate_pairs xi do
# These words are rotate_pairs xi it
# These words are rotate_pairs xu by
# These words are rotate_pairs xu da
# These words are rotate_pairs xu he
# These words are rotate_pairs xu if
# These words are rotate_pairs yah gip
# These words are rotate_pairs yank cero
# These words are rotate_pairs yar act
# These words are rotate_pairs yaw gie
# These words are rotate_pairs yay gig
# These words are rotate_pairs yen flu
# These words are rotate_pairs yeti flap
# These words are rotate_pairs yom kay
# These words are rotate_pairs zax aby
# These words are rotate_pairs zax deb
# These words are rotate_pairs zebu glib
# These words are rotate_pairs zebu jole
# These words are rotate_pairs zee aff
# These words are rotate_pairs zee inn
# These words are rotate_pairs zips lube
# These words are rotate_pairs zoa fug
# These words are rotate_pairs zoa lam

# %% [raw]
# Exercise 6
# Here’s another Puzzler from Car Talk (http://www.cartalk.com/content/puzzlers):
# This was sent in by a fellow named Dan O’Leary. He came upon a common one-syllable, five-letter word recently that has the following unique property. When you remove the first letter, the remaining letters form a homophone of the original word, that is a word that sounds exactly the same. Replace the first letter, that is, put it back and remove the second letter and the result is yet another homophone of the original word. And the question is, what’s the word?
# Now I’m going to give you an example that doesn’t work. Let’s look at the five-letter word, ‘wrack.’ W-R-A-C-K, you know like to ‘wrack with pain.’ If I remove the first letter, I am left with a four-letter word, ’R-A-C-K.’ As in, ‘Holy cow, did you see the rack on that buck! It must have been a nine-pointer!’ It’s a perfect homophone. If you put the ‘w’ back, and remove the ‘r,’ instead, you’re left with the word, ‘wack,’ which is a real word, it’s just not a homophone of the other two words.
# But there is, however, at least one word that Dan and we know of, which will yield two homophones if you remove either of the first two letters to make two, new four-letter words. The question is, what’s the word?
#
# You can use the dictionary from Exercise 1 to check whether a string is in the word list.
#
# To check whether two words are homophones, you can use the CMU Pronouncing Dictionary. You can download it from http://www.speech.cs.cmu.edu/cgi-bin/cmudict or from http://thinkpython2.com/code/c06d and you can also download http://thinkpython2.com/code/pronounce.py, which provides a function named read_dictionary that reads the pronouncing dictionary and returns a Python dictionary that maps from each word to a string that describes its primary pronunciation.
#
# Write a program that lists all the words that solve the Puzzler. Solution: http://thinkpython2.com/code/homophone.py.

# %%
def make_dict():
    global t
    t = {}
    fin = open('words.txt')
    for line in fin:
        word = line.strip().lower()
        t[word]=0
    return t

def make_pron_dict():
    d={}
    fin=open('c06d.txt')
    for line in fin:
        if line[0]=='#':
            continue
        t=line.split()
        word=t[0].lower()
        pron=' '.join(t[1:])
        d[word]=pron
    return d


def find_double_homophones():
    t=make_dict()
    d=make_pron_dict()
    for word in t:
        word1=word[1:]
        word2=word[0]+word[2:]
        if word1 in t and word2 in t and word1 in d and word2 in d and word in d:
            if d[word]==d[word1] and d[word1]==d[word2]:
                print('This word solves the brainteaser:/n',word)
                
find_double_homophones()
# Out:
# This word solves the brainteaser:/n llama
# This word solves the brainteaser:/n llamas
# This word solves the brainteaser:/n scent

# %%
t['hello']
# Out:
# 0
